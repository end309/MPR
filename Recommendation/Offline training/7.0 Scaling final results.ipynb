# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("201-250_gg.txt", sep = ',')

# %%
df.head(10)
# Out:
#    224   1080592   -6.378058878201562e-36
# 0  240   1080592             3.830285e-40
# 1  208   1080592             1.317069e-39
# 2  225   1080592             3.413834e-40
# 3  241   1080592             7.582767e-40
# 4  209   1080592             6.698620e-40
# 5  210   1080592             1.143418e-38
# 6  226   1080592             2.012989e-38
# 7  242   1080592            -3.434308e-41
# 8  243   1080592             2.241338e-39
# 9  227   1080592             2.135285e-38

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler

# %%
scaler = MinMaxScaler(feature_range = (0,1))

# %%
df.columns = ['user_id', 'beh_id', 'freq']

# %%
scaled_data = scaler.fit_transform(df[['freq']])

# %%
df['bin_freq'] = scaled_data

# %%
df.head(50)
# Out:
#     user_id   beh_id          freq  bin_freq
# 0       240  1080592  3.830285e-40  0.004825
# 1       208  1080592  1.317069e-39  0.004825
# 2       225  1080592  3.413834e-40  0.004825
# 3       241  1080592  7.582767e-40  0.004825
# 4       209  1080592  6.698620e-40  0.004825
# 5       210  1080592  1.143418e-38  0.004825
# 6       226  1080592  2.012989e-38  0.004825
# 7       242  1080592 -3.434308e-41  0.004825
# 8       243  1080592  2.241338e-39  0.004825
# 9       227  1080592  2.135285e-38  0.004825
# 10      211  1080592  8.901277e-40  0.004825
# 11      212  1080592  4.666648e-41  0.004825
# 12      228  1080592 -4.966585e-36  0.004822
# 13      244  1080592  4.637162e-40  0.004825
# 14      229  1080592  3.528960e-39  0.004825
# 15      213  1080592  3.765382e-39  0.004825
# 16      245  1080592  4.403236e-39  0.004825
# 17      230  1080592  1.671215e-39  0.004825
# 18      246  1080592 -1.005274e-38  0.004825
# 19      214  1080592  1.650449e-38  0.004825
# 20      231  1080592  9.550817e-40  0.004825
# 21      215  1080592 -5.803356e-35  0.004789
# 22      247  1080592 -1.580601e-40  0.004825
# 23      216  1080592  8.923740e-39  0.004825
# 24      232  1080592  6.042383e-39  0.004825
# 25      248  1080592  5.122024e-38  0.004825
# 26      217  1080592  1.212591e-38  0.004825
# 27      233  1080592  7.946139e-39  0.004825
# 28      201  1080592  6.768315e-38  0.004825
# 29      249  1080592  5.268749e-38  0.004825
# 30      202  1080592  1.386223e-40  0.004825
# 31      218  1080592 -4.172429e-36  0.004823
# 32      234  1080592  3.705961e-39  0.004825
# 33      235  1080592  1.289608e-38  0.004825
# 34      219  1080592  7.360595e-40  0.004825
# 35      203  1080592 -1.023325e-39  0.004825
# 36      220  1080592  2.841109e-39  0.004825
# 37      204  1080592  6.702561e-39  0.004825
# 38      236  1080592  5.013559e-39  0.004825
# 39      205  1080592  1.908640e-38  0.004825
# 40      237  1080592 -1.477556e-40  0.004825
# 41      221  1080592  2.073493e-39  0.004825
# 42      222  1080592  2.057620e-39  0.004825
# 43      206  1080592  8.471594e-40  0.004825
# 44      238  1080592  4.346580e-38  0.004825
# 45      207  1080592  3.243743e-40  0.004825
# 46      223  1080592  3.592767e-38  0.004825
# 47      239  1080592  1.091955e-39  0.004825
# 48      224  1591920  0.000000e+00  0.004825
# 49      240  1591920  0.000000e+00  0.004825

# %%
df.to_csv("201-250_ggs.csv")
